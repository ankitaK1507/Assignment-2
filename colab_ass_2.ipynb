# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitaK1507/Assignment-2/blob/main/colab_ass_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #taking two numbers
a=10
b=5
sum=a+b
print ("sum=",sum)


#declare variables
a=3.2
b="Hello"

#display variables
print("value of a", a)
print ("value of b",b)


#display type of variables
print (" type of a :", type (a))
print ("type of b :",type (b))



 # demonisation of logical operators

a=10
b=5
#logical AND
print ("a>5 and b>2:",a>5 and b>2)
# Out:
# sum= 15
# value of a 3.2
# value of b Hello
#  type of a : <class 'float'>
# type of b : <class 'str'>
# a>5 and b>2: True
